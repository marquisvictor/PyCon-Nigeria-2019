# %% [markdown]
# <img src="pyconng.png">
#
#
# # Twitter Data Mining: Gathering and Preprocessing Location Based Tweets for Textual Analysis and Insights
#
#
# ## PyCon Nigeria Workshop 2019
#
# ### Delivered by: Victor Irekponor, Data scientist, [RETINA-AI Health Inc](https://www.linkedin.com/company/retina-ai/?originalSubdomain=ng)
#
# ### Table of Contents:
# <ul>
#
#     <li> Abstract</li>
#     <li> Introduction and Description</li>
#     <li> Exploring Twitter's API</li>
#     <li> Mining Tweets</li>
#     <li> Preprocessing & cleaning the tweets</li>
#     <li> Analysis</li>
#     <li> Sentiment Analysis</li>
#     <li> Time Series Analysis from Tweets Data</li>
#
#
# </ul>
#
# ### <p style="text-align: center;">Abstract</p>
#
# Social media is an integral part of people’s daily lives, millions of unstructured data are sent to the cloud every second, providing free and unbiased information and opinion practically on every discourse. Using Twitter as case study, we will be mining location based Tweets to garner more insights through a demonstrated step by step analytical approach of qeurying twitter's API, and Twitter search engine for location based tweets.
#
#
# ### <p style="text-align: center;">Introduction</p>
#
# Social media has evolved to be an integral part of people’s daily lives, millions of unstructured data are sent to the cloud every second, providing free and unbiased information and opinion practically on every discourse. Every second, an average of around 6000 tweets are tweeted on Twitter which corresponds to over 350,000 tweets sent per minute, [500 million tweets per day and around 200 billion tweets per year](https://www.internetlivestats.com/twitter-statistics/)
#
# For ease of understanding and simplicity, this workshop would be sub divided into five phases, we would:
# 1. Take a sneak peak at the concept of Data Mining
#
#
# 2. Download these electronic unstructured data.
#
#
# 3. Optimized Modified GetOldTweets3 (OMGOT) to download twitter data with minimal programming knowledge
#
#
# 4. Preprocess these harvested data getting them ready for analysis.
#
#
# 4. Passing this preprocessed data through a sentiment analysis pipeline
#
#
# 5. Visualising Results from Ins
#
#
# ### What really is Data Mining ?
#
# <img src="download (1).jpeg">
#
# As the name implies, Data mining in its simplest form is the process of analysing data which involves its collection and storage in databases, so as to facilitate business decision making processes, and other information requirements to ultimately cut costs and increase revenue.
# [Data mining is also known as data discovery or knoledge discovery.](https://www.techopedia.com/definition/1181/data-mining)
#
#
# ### Downloading Tweets Dataset.
#
# Twitter basically has two APIs for developers who have accounts with them to retrieve data,
# 1. the Representative State Transfer (REST) API and
# 2. the Streaming API
#
# The REST API also known as the Representative state transfer API allows you mine backdated tweets. The Streaming API, however, allows you to gather tweets in real time. One can then infer that they both work differently. The only draw back or constraint with Twitter’s official API is that you can’t get Tweets older than a week (7 days), with rate limits to it, except you are using the Streaming API and can wait for dyas to mine enough big data. More often than not, you realize that you don’t have that time.
#
#
# Nonetheless, there are ways we can access and mine older tweets by just scraping the twitter search engine, here, we don’t need Twitter’s Authentication; so, we won’t be affected by Twitter’s rate limits.
#
# <img src="excited.jpeg">
#
# ### Approach
#
# The very standard approach for twitter data mining would be first creating a developer account with Twitter, and then querying Twitter's RESTful API to download the users tweets with some other meta-data such as retweets, likes, favourites, data and time, username, et cetera. with the aid of libraries such as Tweepy, Tweetr, and Twython
#
# But for this workshop, we would be using [a simpler tool](https://github.com/marquisvictor/Optimized-Modified-GetOldTweets3-OMGOT) i modified with a little optimisation to get twitter data easily with minimal programming knowledge required and from command line, originally written by: [Jefferson Henrique](https://github.com/Jefferson-Henrique/GetOldTweets-python)
#
# ### [Optimized-Modified-GetOldTweets3-OMGOT](https://github.com/marquisvictor/Optimized-Modified-GetOldTweets3-OMGOT)
#
# **Optimized-Modified-GetOldTweets3-OMGOT** is an improvement fork of the Original **GetOldTweets-Python**  tool written by [Jefferson Henrique](https://github.com/Jefferson-Henrique/GetOldTweets-python) to mine old and backdated tweets, It bypasses some limitations/restrictions of the Twitter API. For instance, using twitter’s API you can not mine tweets older than seven days, similarly for a single search query, twitter only gives 100 results of the current week. If you need to download time-line tweets, or curate a very large dataset, this is not very helpful. Also OMGOT was optimized such that little to no serious programming experience is required to download twitter data.
#
#
# ### Prerequisites
# - Python3.x   ```pip install python```
# - pyQuery   ```pip install pyquery```
# - lxml      ```pip install lxml```
# - pandas, numpy, matplotlib
# - VADER   ```pip install vaderSentiment```
#
# After fulfilling these prerequisites, Lets head down to my [GitHub](https://github.com/marquisvictor/Optimized-Modified-GetOldTweets3-OMGOT), to fork and/or clone my improvement fork of [Mottl’s python3 version](https://github.com/Mottl/GetOldTweets3) of the tool which is also an improvement fork of the original package written by [Jefferson Henrique](https://github.com/Jefferson-Henrique/GetOldTweets-python)
#
#
# <img src="three.gif">
#
# Once you have cloned or downloaded the repo to your personal github or local machine, you can now start getting your old/backdated twitter data for any kind of analysis by:
#
# 1. ```cd``` into the downloaded GetOldTweets3 folder on your local machine and fire up cmd right in that same folder.
#
#
# 2. Run the commands from the github readme to start downloading the twitter data which would then be saved on your computer as an output.csv file. But you can specify a name to save your downloaded dataset by passing a “name”.csv to the ```--output``` argument. For instance: ```--output dataset.csv```.
#
#
# > <h3>Now, getting our hands dirtier with more examples. Lets say we need to download tweets by a specific User.<h3/>
#
# We simply do step 1, as stated above, and type in the following command culled from the Github repo:
#
# ```python``` GetOldTweets3.py ```--username``` "mo4president"  ```--maxtweets``` 50 ```--output``` dataset.csv
#
# this would query the twitter search engine and download all of the tweets made by '@mo4president', you can also specify ```--maxtweets``` to control the amount of tweets you need, and ```--output``` to specify the output name. It should be noted that Leaving out the ```--maxtweets``` argument basically downloads all of the tweets by the user.
#
# Also if you need to download tweets with respect to a particular keyword e.g “rent” over a period of time from like say 2014 till date and within a geographic geolocation, which is about 5 years worth of old tweets and could accumulate to millions of tweets data depending on your search radius. The following commands would suffice:
#
# ```python``` GetOldTweets3.py ```--querysearch``` "rent" ```--near``` "6.52, 3.37" ```--within``` 40km ```--maxtweets``` 350 ```--output``` rent.csv ```--since``` 2014-01-01 ```--until``` 2019-08-31
#
#
# So this command above would fetch you all the tweets that contains the word “rent”, within a 40km radius of the latitudinal and longitudinal coordinates of Lagos state from 2014 till date, and would store the results in a rent.csv file that would be saved in that same directory you’re working on. The maxtweets here would return 350 tweets because that is what was specified.
#
# ###  [Now lets go ahead to download our tweet dataset using BbNaija as the search keyword, for the past 5 years, looking at tweets sent from Lagos state alone. ](https://github.com/marquisvictor/Optimized-Modified-GetOldTweets3-OMGOT)

# %% [markdown]
# ### Loading in the Downloaded dataset and Preprocessing after downloading

# %%
import pandas as pd          # Python's library for dataframe manipulation
from pprint import pprint    # Library for neat printing 
import re                    # Python's library for regular expressions 
import matplotlib.pyplot as plt

traffic = pd.read_csv('traffic.csv')# parse_dates=True)     # Loading the dataset to a pandas dataframe

# %%
traffic.head(5) # VIewing the first 5 rows in the dataframe
# Out:
#                   date     username         to  replies  retweets  favorites  \
# 0  2019-09-30 22:59:24   Rosa_rose0        NaN        0         3          2
# 1  2019-09-30 22:50:09   Rosa_rose0  FollyFlo1        1         0          1
# 2  2019-09-30 22:35:42   Rosa_rose0        NaN        0         3          2
# 3  2019-09-30 22:31:09       HoH9ja    Murmony        1         0          0
# 4  2019-09-30 22:24:19  LagosMegida        NaN        0         1          1
#
#                                                 text  geo  \
# 0  Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...  NaN
# 1  I didn't see where to DM youpic.twitter.com/Z3...  NaN
# 2  We are selling now #EmeryOut #construction #re...  NaN
# 3  Baba, I just dey reach house now... traffic ma...  NaN
# 4  The level of bad roads & traffic is something ...  NaN
#
#                                             mentions  \
# 0                  @bustopsng @KBragga @Gidi_Traffic
# 1                                                NaN
# 2  @KBragga @STEMGemsBook @DCTechAfrica2 @Gidi_Tr...
# 3                                                NaN
# 4                           @Gidi_Traffic @bustopsng
#
#                                             hashtags                   id  \
# 0                 #BBNaija #EmeryOut #mondaythoughts  1178806579287773184
# 1                                                NaN  1178804251545477122
# 2  #EmeryOut #construction #renovations #Nigeria ...  1178800613938872322
# 3                                                NaN  1178799469661474816
# 4                #mufc #mondaythoughts #lagostraffic  1178797749510250496
#
#                                            permalink
# 0  https://twitter.com/Rosa_rose0/status/11788065...
# 1  https://twitter.com/Rosa_rose0/status/11788042...
# 2  https://twitter.com/Rosa_rose0/status/11788006...
# 3  https://twitter.com/HoH9ja/status/117879946966...
# 4  https://twitter.com/LagosMegida/status/1178797...

# %%
ds.structdata.describe(traffic)
# Out:
# First five data points
#                   date     username         to  replies  retweets  favorites  \
# 0  2019-09-30 22:59:24   Rosa_rose0        NaN        0         3          2
# 1  2019-09-30 22:50:09   Rosa_rose0  FollyFlo1        1         0          1
# 2  2019-09-30 22:35:42   Rosa_rose0        NaN        0         3          2
# 3  2019-09-30 22:31:09       HoH9ja    Murmony        1         0          0
# 4  2019-09-30 22:24:19  LagosMegida        NaN        0         1          1
#
#                                                 text  \
# 0  Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# 1  I didn't see where to DM youpic.twitter.com/Z3...
# 2  We are selling now #EmeryOut #construction #re...
# 3  Baba, I just dey reach house now... traffic ma...
# 4  The level of bad roads & traffic is something ...
#
#                                             mentions  \
# 0                  @bustopsng @KBragga @Gidi_Traffic
# 1                                                NaN
# 2  @KBragga @STEMGemsBook @DCTechAfrica2 @Gidi_Tr...
# 3                                                NaN
# 4                           @Gidi_Traffic @bustopsng
#
#                                             hashtags  \
# 0                 #BBNaija #EmeryOut #mondaythoughts
# 1                                                nan
# 2  #EmeryOut #construction #renovations #Nigeria ...
# 3                                                nan
# 4                #mufc #mondaythoughts #lagostraffic
#
#                                          tweet_clean  \
# 0  Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# 1  I didn't see where to DM youpic.twitter.com/Z3...
# 2  We are selling now #EmeryOut #construction #re...
# 3  Baba I just dey reach house now.. traffic madd...
# 4  The level of bad roads traffic is something el...
#
#                                        hashtag_clean tweet_sentiment  \
# 0                    BBNaija EmeryOut mondaythoughts         neutral
# 1                                                nan         neutral
# 2  EmeryOut construction renovations Nigeria Patr...         neutral
# 3                                                nan        positive
# 4                   mufc mondaythoughts lagostraffic        negative
#
#   hashtag_sentiment
# 0           neutral
# 1           neutral
# 2           neutral
# 3           neutral
# 4           neutral
# Last five data points
#                       date      username        to  replies  retweets  \
# 23595  2015-05-31 14:42:31    Keneric007       NaN        0         0
# 23596  2015-05-31 11:28:53  bettyjewelry       NaN        0         0
# 23597  2015-05-31 09:43:28      valonyia       NaN        0         0
# 23598  2015-05-31 07:57:26     Walex123_  PoliceNG        0         0
# 23599  2015-05-31 06:51:43      LLins___       NaN        0         0
#
#        favorites                                               text  \
# 23595          0  Traffic in Lagos is as bad as ......... @Silve...
# 23596          0  @Gidi_Traffic #ALERT Pls SOS from MRS grammer ...
# 23597          0  @Gidi_Traffic Please I am looking for a clean ...
# 23598          0  @PoliceNG around 6am. Causing traffic jam. And...
# 23599          0  Abuja by car @Gidi_Traffic pic.twitter.com/8LM...
#
#             mentions hashtags  \
# 23595    @Silverbird      nan
# 23596  @Gidi_Traffic   #ALERT
# 23597  @Gidi_Traffic      nan
# 23598      @PoliceNG      nan
# 23599  @Gidi_Traffic      nan
#
#                                              tweet_clean hashtag_clean  \
# 23595  Traffic in Lagos is as bad as ........ Galleri...           nan
# 23596  _Traffic #ALERT Pls SOS from MRS grammer schoo...         ALERT
# 23597  _Traffic Please I am looking for a clean 9ja u...           nan
# 23598  around 6am Causing traffic jam And even In som...           nan
# 23599   Abuja by car _Traffic pic.twitter.com/8LMyE9FYRq           nan
#
#       tweet_sentiment hashtag_sentiment
# 23595        negative           neutral
# 23596         neutral           neutral
# 23597        positive           neutral
# 23598         neutral           neutral
# 23599         neutral           neutral
# Shape of  data set: (23600, 13)
#
#
# Size of  data set: 306800
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#                   Data Type
# date                 object
# username             object
# to                   object
# replies               int64
# retweets              int64
# favorites             int64
# text                 object
# mentions             object
# hashtags             object
# tweet_clean          object
# hashtag_clean        object
# tweet_sentiment      object
# hashtag_sentiment    object
# Column(s) {'date'} should be in Datetime format. Use the [to_date] function in datasist.feature_engineering to coonvert to Pandas Datetime format
#
#
# Numerical Features in Data set
# ['replies', 'retweets', 'favorites']
#
#
# Statistical Description of Columns
#             replies      retweets     favorites
# count  23600.000000  23600.000000  23600.000000
# mean       0.475975      1.079407      1.638008
# std        2.296955     13.079247     16.600128
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      1.000000
# max      163.000000   1588.000000   1405.000000
# Categorical Features in Data set
# ['date',
#  'username',
#  'to',
#  'text',
#  'mentions',
#  'hashtags',
#  'tweet_clean',
#  'hashtag_clean',
#  'tweet_sentiment',
#  'hashtag_sentiment']
# Unique class Count of Categorical features
# <style  type="text/css" >
#     #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.7%, transparent 28.7%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.8%, transparent 20.8%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.9%, transparent 95.9%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.8%, transparent 18.8%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.7%, transparent 10.7%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.7%, transparent 10.7%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }</style><table id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Unique Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row0_col0" class="data row0 col0" >date</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row0_col1" class="data row0 col1" >23224</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row1_col0" class="data row1 col0" >username</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row1_col1" class="data row1 col1" >6673</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row2_col0" class="data row2 col0" >to</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row2_col1" class="data row2 col1" >4842</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row3_col0" class="data row3 col0" >text</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row3_col1" class="data row3 col1" >22276</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row4_col0" class="data row4 col0" >mentions</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row4_col1" class="data row4 col1" >4369</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row5_col0" class="data row5 col0" >hashtags</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row5_col1" class="data row5 col1" >2487</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row6_col0" class="data row6 col0" >tweet_clean</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row6_col1" class="data row6 col1" >22082</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row7_col0" class="data row7 col0" >hashtag_clean</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row7_col1" class="data row7 col1" >2485</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row8_col0" class="data row8 col0" >tweet_sentiment</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row8_col1" class="data row8 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row9_col0" class="data row9 col0" >hashtag_sentiment</td>
#                         <td id="T_c4d9bfa8_faef_11e9_9f46_b8763ff5f941row9_col1" class="data row9 col1" >3</td>
#             </tr>
#     </tbody></table>
# Missing Values in Data
#              features  missing_counts  missing_percent
# 0                date               0             0.00
# 1            username               0             0.00
# 2                  to           14792            62.68
# 3             replies               0             0.00
# 4            retweets               0             0.00
# 5           favorites               0             0.00
# 6                text               0             0.00
# 7            mentions           12840            54.41
# 8            hashtags               0             0.00
# 9         tweet_clean               0             0.00
# 10      hashtag_clean               0             0.00
# 11    tweet_sentiment               0             0.00
# 12  hashtag_sentiment               0             0.00

# %%
traffic = traffic.drop(['geo', 'id', 'permalink'], axis=1) # Dropping irrelevant columns 
traffic.head().transpose()
# Out:
#                                                            0  \
# date                                     2019-09-30 22:59:24
# username                                          Rosa_rose0
# to                                                       NaN
# replies                                                    0
# retweets                                                   3
# favorites                                                  2
# text       Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# mentions                   @bustopsng @KBragga @Gidi_Traffic
# hashtags                  #BBNaija #EmeryOut #mondaythoughts
#
#                                                            1  \
# date                                     2019-09-30 22:50:09
# username                                          Rosa_rose0
# to                                                 FollyFlo1
# replies                                                    1
# retweets                                                   0
# favorites                                                  1
# text       I didn't see where to DM youpic.twitter.com/Z3...
# mentions                                                 NaN
# hashtags                                                 NaN
#
#                                                            2  \
# date                                     2019-09-30 22:35:42
# username                                          Rosa_rose0
# to                                                       NaN
# replies                                                    0
# retweets                                                   3
# favorites                                                  2
# text       We are selling now #EmeryOut #construction #re...
# mentions   @KBragga @STEMGemsBook @DCTechAfrica2 @Gidi_Tr...
# hashtags   #EmeryOut #construction #renovations #Nigeria ...
#
#                                                            3  \
# date                                     2019-09-30 22:31:09
# username                                              HoH9ja
# to                                                   Murmony
# replies                                                    1
# retweets                                                   0
# favorites                                                  0
# text       Baba, I just dey reach house now... traffic ma...
# mentions                                                 NaN
# hashtags                                                 NaN
#
#                                                            4
# date                                     2019-09-30 22:24:19
# username                                         LagosMegida
# to                                                       NaN
# replies                                                    0
# retweets                                                   1
# favorites                                                  1
# text       The level of bad roads & traffic is something ...
# mentions                            @Gidi_Traffic @bustopsng
# hashtags                 #mufc #mondaythoughts #lagostraffic

# %%
def clean_tweet(tweet):    
    '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.      ''' 
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)*_#:.?", " ", tweet).split())

def clean_hashtags(hashtag):    
    '''
        Utility function to clean tweet hashtags by removing the hastags and special characters
        using simple regex statements.
        '''     
    return ' '.join(re.sub("#", " ", hashtag).split())

# %% [markdown]
# ### Applying the custom functions to clean the Tweet text and Hashtag column in the dataframe

# %%
traffic.text = traffic.text.astype(str)    # First change the data type to string.   
traffic.hashtags = traffic.hashtags.astype(str)  # First change the data type to string.

# %%
traffic['tweet_clean'] = traffic.text.apply(clean_tweet)  # Applying the cleaning function here
traffic['hashtag_clean'] = traffic.hashtags.apply(clean_hashtags)

# %%
traffic.head().T
# Out:
#                                                                0  \
# date                                         2019-09-30 22:59:24
# username                                              Rosa_rose0
# to                                                           NaN
# replies                                                        0
# retweets                                                       3
# favorites                                                      2
# text           Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# mentions                       @bustopsng @KBragga @Gidi_Traffic
# hashtags                      #BBNaija #EmeryOut #mondaythoughts
# tweet_clean    Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# hashtag_clean                    BBNaija EmeryOut mondaythoughts
#
#                                                                1  \
# date                                         2019-09-30 22:50:09
# username                                              Rosa_rose0
# to                                                     FollyFlo1
# replies                                                        1
# retweets                                                       0
# favorites                                                      1
# text           I didn't see where to DM youpic.twitter.com/Z3...
# mentions                                                     NaN
# hashtags                                                     nan
# tweet_clean    I didn't see where to DM youpic.twitter.com/Z3...
# hashtag_clean                                                nan
#
#                                                                2  \
# date                                         2019-09-30 22:35:42
# username                                              Rosa_rose0
# to                                                           NaN
# replies                                                        0
# retweets                                                       3
# favorites                                                      2
# text           We are selling now #EmeryOut #construction #re...
# mentions       @KBragga @STEMGemsBook @DCTechAfrica2 @Gidi_Tr...
# hashtags       #EmeryOut #construction #renovations #Nigeria ...
# tweet_clean    We are selling now #EmeryOut #construction #re...
# hashtag_clean  EmeryOut construction renovations Nigeria Patr...
#
#                                                                3  \
# date                                         2019-09-30 22:31:09
# username                                                  HoH9ja
# to                                                       Murmony
# replies                                                        1
# retweets                                                       0
# favorites                                                      0
# text           Baba, I just dey reach house now... traffic ma...
# mentions                                                     NaN
# hashtags                                                     nan
# tweet_clean    Baba I just dey reach house now.. traffic madd...
# hashtag_clean                                                nan
#
#                                                                4
# date                                         2019-09-30 22:24:19
# username                                             LagosMegida
# to                                                           NaN
# replies                                                        0
# retweets                                                       1
# favorites                                                      1
# text           The level of bad roads & traffic is something ...
# mentions                                @Gidi_Traffic @bustopsng
# hashtags                     #mufc #mondaythoughts #lagostraffic
# tweet_clean    The level of bad roads traffic is something el...
# hashtag_clean                   mufc mondaythoughts lagostraffic

# %% [markdown]
# At this stage, we have the dataset cleaned and preprocessed in a dataframe already for for any kind of text analytics pipeline we want to run it through, be it time-series analyis, Sentiment Analysis, Topic modelling, Social network Analysis, Visualisations et cetera. But for the purpose of this workshop, we would be creating a sentiment analysis pipeline, Using [VADER Setiment analyser](https://github.com/cjhutto/vaderSentiment), and [TextBlob](https://textblob.readthedocs.io/en/dev/)

# %% [markdown]
# ### Using TextBlob
#
# #### [follow this link for a more comprehensive tutorial on the Textblob library for natural language processing operations](https://www.analyticsvidhya.com/blog/2018/02/natural-language-processing-for-beginners-using-textblob/)

# %%
from textblob import TextBlob   # For sentiment Analysis

# %%
def get_tweet_sentiment(tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        
        analysis = TextBlob(clean_tweet(tweet))  # create TextBlob object of tweet text
    
        
        if analysis.sentiment.polarity > 0:      # set sentiment
            return 'positive'        
        elif analysis.sentiment.polarity == 0:
            return 'neutral'        
        else:
            return 'negative'

# %% [markdown]
# ### Getting the sentiments polarity for each tweets in the dataset using TextBlob library

# %%
traffic['tweet_sentiment'] = traffic.tweet_clean.apply(get_tweet_sentiment)
traffic['hashtag_sentiment'] = traffic.hashtag_clean.apply(get_tweet_sentiment)

# %%
list(traffic[traffic.tweet_sentiment=='negative'].text.head())
# Out:
# ['The level of bad roads & traffic is something else.. Our Governor will resume in January hopefully.. ..pray it gets better for residents then... @Gidi_Traffic @bustopsng #mufc #mondaythoughts #lagostraffic',
#  'Fucking traffic by this time',
#  'After you descend the Cele-Okota link Bridge enroute Okota, the bad portion of the road there is causing wavy traffic on OGUNLANA str down to Ijesha road and environs. I believe we still have a Governor and Loca government chairman. #happyindependenceday',
#  'Our response riders are still in Ojodu - Berger inward Ogun State managing traffic and ensuring there is no break down of law and order. pic.twitter.com/Y0fU17bNLd',
#  'Have you ever thought about the effect of Lagos traffic on your health?? . . Lagos State with a population of 21 million and With over 5 million registered vehicles on its roads, Lagos has an average of 200 vehicles… https://www.instagram.com/p/B3DDdzvFVUW/?igshid=1ly66q9u4tcmb …']

# %%
traffic.hashtag_sentiment.value_counts()
# Out:
# neutral     23519
# positive       62
# negative       19
# Name: hashtag_sentiment, dtype: int64

# %%
traffic.tweet_sentiment.value_counts()
# Out:
# neutral     11261
# positive     7688
# negative     4651
# Name: tweet_sentiment, dtype: int64

# %%
# %matplotlib inline
traffic.tweet_sentiment.value_counts().plot(kind='barh')
plt.title('Chart displaying number tweet sentiment against Number Of Tweets')
# Out:
# Text(0.5,1,'Chart displaying number tweet sentiment against Number Of Tweets')

# %% [markdown]
# ### Using VADER

# %% [markdown]
# #### [Follow this link for a more comprehensive tutorial on VADER Sentiments](https://medium.com/analytics-vidhya/simplifying-social-media-sentiment-analysis-using-vader-in-python-f9e6ec6fc52f)

# %%
vader_df = pd.read_csv('traffic.csv')
vader_df = vader_df.drop(['geo', 'id', 'permalink'], axis=1) # Dropping irrelevant columns

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()   # Initialize the sentiment intensity analyzer

# %%
nega = []
posi = []
neut = []
comp = []

conv = list((traffic['tweet_clean']))

for n in conv:
    nega.append(analyzer.polarity_scores(n)['neg'])
    
for p in conv:
    posi.append(analyzer.polarity_scores(p)['pos'])
                
for nt in conv:
    neut.append(analyzer.polarity_scores(nt)['neu'])
                
for c in conv:
    comp.append(analyzer.polarity_scores(c)['compound'])

vader_df['Vad_pos_tweets'] = posi
vader_df['Vad_neg_tweets'] = nega
vader_df['Vad_neutr_tweets'] = neut
vader_df['Vad_comp_tweets'] = comp

vader_df.head()
# Out:
#                   date     username         to  replies  retweets  favorites  \
# 0  2019-09-30 22:59:24   Rosa_rose0        NaN        0         3          2
# 1  2019-09-30 22:50:09   Rosa_rose0  FollyFlo1        1         0          1
# 2  2019-09-30 22:35:42   Rosa_rose0        NaN        0         3          2
# 3  2019-09-30 22:31:09       HoH9ja    Murmony        1         0          0
# 4  2019-09-30 22:24:19  LagosMegida        NaN        0         1          1
#
#                                                 text  \
# 0  Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# 1  I didn't see where to DM youpic.twitter.com/Z3...
# 2  We are selling now #EmeryOut #construction #re...
# 3  Baba, I just dey reach house now... traffic ma...
# 4  The level of bad roads & traffic is something ...
#
#                                             mentions  \
# 0                  @bustopsng @KBragga @Gidi_Traffic
# 1                                                NaN
# 2  @KBragga @STEMGemsBook @DCTechAfrica2 @Gidi_Tr...
# 3                                                NaN
# 4                           @Gidi_Traffic @bustopsng
#
#                                             hashtags  Vad_pos_tweets  \
# 0                 #BBNaija #EmeryOut #mondaythoughts           0.000
# 1                                                NaN           0.000
# 2  #EmeryOut #construction #renovations #Nigeria ...           0.000
# 3                                                NaN           0.253
# 4                #mufc #mondaythoughts #lagostraffic           0.169
#
#    Vad_neg_tweets  Vad_neutr_tweets  Vad_comp_tweets
# 0           0.000             1.000           0.0000
# 1           0.000             1.000           0.0000
# 2           0.000             1.000           0.0000
# 3           0.000             0.747           0.5267
# 4           0.106             0.725           0.2732

# %%
vader_df.dtypes
# Out:
# date                 object
# username             object
# to                   object
# replies               int64
# retweets              int64
# favorites             int64
# text                 object
# mentions             object
# hashtags             object
# Vad_pos_tweets      float64
# Vad_neg_tweets      float64
# Vad_neutr_tweets    float64
# Vad_comp_tweets     float64
# dtype: object

# %%
final_setiment = []
for i in range(len(vader_df)):
    if vader_df.iloc[i]['Vad_pos_tweets'] >= 0.7:
        final_setiment.append('positive')
    elif vader_df.iloc[i]['Vad_neg_tweets'] >= 0.7:
        final_setiment.append('negative') 
    else:
        final_setiment.append('neutral')

# %%
vader_df['final_setiment'] = final_setiment
len(final_setiment), len(vader_df)
# Out:
# (23600, 23600)

# %%
#vader_df.sample(10)

# %%
(list(vader_df[vader_df.final_setiment=='negative'].text.head(20)))
# Out:
# ['Poor kid',
#  'Ghost mode!',
#  'I swear.',
#  'Everybody lo stupid nah.',
#  'I will tag her o. Broke ass!!!',
#  'Useless woman',
#  'Stupid traffic',
#  'Bloody traffic.',
#  'Seriously???',
#  'Traffic wtf',
#  'I weak',
#  'No o',
#  'Cry ur own cry',
#  'No',
#  'Savage',
#  'I disagree',
#  'Kakakakakaka scam',
#  'Sorry',
#  'I no envy you',
#  'Mad o']

# %%
vader_df.Vad_comp_tweets.max()
# Out:
# 0.9815

# %% [markdown]
# ### Insights

# %%
vader_df.Vad_comp_tweets.plot(kind='hist', figsize=(15,8));

# %% [markdown]
# ### <p style="text-align: center;">Now that we've established how to mine twitter data and preprocess it for analysis. Lets get some more insights; looking at the time trend analysis of negative tweets on traffic over the last 5 years.</p>

# %%
vader_df['date'] = pd.to_datetime(vader_df['date'])
vader_df.index = vader_df['date']
vader_df.resample('w').mean()['Vad_neg_tweets'].plot(figsize=(25, 9), color='r', legend='True',
                                                    title='Timeseries Analysis of Negative Tweets');
#vader_df



#vader_df.Vad_neg_tweets['2019'].sort_index()

# %% [markdown]
# ## WordCloud Analysis

# %%
from wordcloud import WordCloud

# %%
neg_texts = str(list(vader_df[vader_df.final_setiment=='negative'].text))

# %%
wordcloud = WordCloud().generate(neg_texts)

# %%
plt.axis("off")
plt.figure(figsize=(15,18))
plt.imshow(wordcloud, interpolation='bilinear')

# %% [markdown]
# # The END!

# %%
import datasist as ds

# %%
ds.structdata.describe(traffic)
# Out:
# First five data points
#                   date     username         to  replies  retweets  favorites  \
# 0  2019-09-30 22:59:24   Rosa_rose0        NaN        0         3          2
# 1  2019-09-30 22:50:09   Rosa_rose0  FollyFlo1        1         0          1
# 2  2019-09-30 22:35:42   Rosa_rose0        NaN        0         3          2
# 3  2019-09-30 22:31:09       HoH9ja    Murmony        1         0          0
# 4  2019-09-30 22:24:19  LagosMegida        NaN        0         1          1
#
#                                                 text  \
# 0  Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# 1  I didn't see where to DM youpic.twitter.com/Z3...
# 2  We are selling now #EmeryOut #construction #re...
# 3  Baba, I just dey reach house now... traffic ma...
# 4  The level of bad roads & traffic is something ...
#
#                                             mentions  \
# 0                  @bustopsng @KBragga @Gidi_Traffic
# 1                                                NaN
# 2  @KBragga @STEMGemsBook @DCTechAfrica2 @Gidi_Tr...
# 3                                                NaN
# 4                           @Gidi_Traffic @bustopsng
#
#                                             hashtags  \
# 0                 #BBNaija #EmeryOut #mondaythoughts
# 1                                                nan
# 2  #EmeryOut #construction #renovations #Nigeria ...
# 3                                                nan
# 4                #mufc #mondaythoughts #lagostraffic
#
#                                          tweet_clean  \
# 0  Sco pa tu manaa #BBNaija #EmeryOut #mondaythou...
# 1  I didn't see where to DM youpic.twitter.com/Z3...
# 2  We are selling now #EmeryOut #construction #re...
# 3  Baba I just dey reach house now.. traffic madd...
# 4  The level of bad roads traffic is something el...
#
#                                        hashtag_clean tweet_sentiment  \
# 0                    BBNaija EmeryOut mondaythoughts         neutral
# 1                                                nan         neutral
# 2  EmeryOut construction renovations Nigeria Patr...         neutral
# 3                                                nan        positive
# 4                   mufc mondaythoughts lagostraffic        negative
#
#   hashtag_sentiment
# 0           neutral
# 1           neutral
# 2           neutral
# 3           neutral
# 4           neutral
# Last five data points
#                       date      username        to  replies  retweets  \
# 23595  2015-05-31 14:42:31    Keneric007       NaN        0         0
# 23596  2015-05-31 11:28:53  bettyjewelry       NaN        0         0
# 23597  2015-05-31 09:43:28      valonyia       NaN        0         0
# 23598  2015-05-31 07:57:26     Walex123_  PoliceNG        0         0
# 23599  2015-05-31 06:51:43      LLins___       NaN        0         0
#
#        favorites                                               text  \
# 23595          0  Traffic in Lagos is as bad as ......... @Silve...
# 23596          0  @Gidi_Traffic #ALERT Pls SOS from MRS grammer ...
# 23597          0  @Gidi_Traffic Please I am looking for a clean ...
# 23598          0  @PoliceNG around 6am. Causing traffic jam. And...
# 23599          0  Abuja by car @Gidi_Traffic pic.twitter.com/8LM...
#
#             mentions hashtags  \
# 23595    @Silverbird      nan
# 23596  @Gidi_Traffic   #ALERT
# 23597  @Gidi_Traffic      nan
# 23598      @PoliceNG      nan
# 23599  @Gidi_Traffic      nan
#
#                                              tweet_clean hashtag_clean  \
# 23595  Traffic in Lagos is as bad as ........ Galleri...           nan
# 23596  _Traffic #ALERT Pls SOS from MRS grammer schoo...         ALERT
# 23597  _Traffic Please I am looking for a clean 9ja u...           nan
# 23598  around 6am Causing traffic jam And even In som...           nan
# 23599   Abuja by car _Traffic pic.twitter.com/8LMyE9FYRq           nan
#
#       tweet_sentiment hashtag_sentiment
# 23595        negative           neutral
# 23596         neutral           neutral
# 23597        positive           neutral
# 23598         neutral           neutral
# 23599         neutral           neutral
# Shape of  data set: (23600, 13)
#
#
# Size of  data set: 306800
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#                   Data Type
# date                 object
# username             object
# to                   object
# replies               int64
# retweets              int64
# favorites             int64
# text                 object
# mentions             object
# hashtags             object
# tweet_clean          object
# hashtag_clean        object
# tweet_sentiment      object
# hashtag_sentiment    object
# Column(s) {'date'} should be in Datetime format. Use the [to_date] function in datasist.feature_engineering to coonvert to Pandas Datetime format
#
#
# Numerical Features in Data set
# ['replies', 'retweets', 'favorites']
#
#
# Statistical Description of Columns
#             replies      retweets     favorites
# count  23600.000000  23600.000000  23600.000000
# mean       0.475975      1.079407      1.638008
# std        2.296955     13.079247     16.600128
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      1.000000
# max      163.000000   1588.000000   1405.000000
# Categorical Features in Data set
# ['date',
#  'username',
#  'to',
#  'text',
#  'mentions',
#  'hashtags',
#  'tweet_clean',
#  'hashtag_clean',
#  'tweet_sentiment',
#  'hashtag_sentiment']
# Unique class Count of Categorical features
# <style  type="text/css" >
#     #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.7%, transparent 28.7%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.8%, transparent 20.8%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.9%, transparent 95.9%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.8%, transparent 18.8%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.7%, transparent 10.7%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.7%, transparent 10.7%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_b4f3753a_faee_11e9_9f46_b8763ff5f941row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }</style><table id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Unique Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row0_col0" class="data row0 col0" >date</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row0_col1" class="data row0 col1" >23224</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row1_col0" class="data row1 col0" >username</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row1_col1" class="data row1 col1" >6673</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row2_col0" class="data row2 col0" >to</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row2_col1" class="data row2 col1" >4842</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row3_col0" class="data row3 col0" >text</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row3_col1" class="data row3 col1" >22276</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row4_col0" class="data row4 col0" >mentions</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row4_col1" class="data row4 col1" >4369</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row5_col0" class="data row5 col0" >hashtags</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row5_col1" class="data row5 col1" >2487</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row6_col0" class="data row6 col0" >tweet_clean</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row6_col1" class="data row6 col1" >22082</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row7_col0" class="data row7 col0" >hashtag_clean</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row7_col1" class="data row7 col1" >2485</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row8_col0" class="data row8 col0" >tweet_sentiment</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row8_col1" class="data row8 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row9_col0" class="data row9 col0" >hashtag_sentiment</td>
#                         <td id="T_b4f3753a_faee_11e9_9f46_b8763ff5f941row9_col1" class="data row9 col1" >3</td>
#             </tr>
#     </tbody></table>
# Missing Values in Data
#              features  missing_counts  missing_percent
# 0                date               0             0.00
# 1            username               0             0.00
# 2                  to           14792            62.68
# 3             replies               0             0.00
# 4            retweets               0             0.00
# 5           favorites               0             0.00
# 6                text               0             0.00
# 7            mentions           12840            54.41
# 8            hashtags               0             0.00
# 9         tweet_clean               0             0.00
# 10      hashtag_clean               0             0.00
# 11    tweet_sentiment               0             0.00
# 12  hashtag_sentiment               0             0.00
